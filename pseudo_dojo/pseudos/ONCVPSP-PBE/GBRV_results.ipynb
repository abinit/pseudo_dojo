# %%
# %matplotlib inline
from pseudo_dojo.core.pseudos import DojoTable

# %%
table = DojoTable.from_dir(".")

# %%
fig = table.plot_dfgbrv_dist(tight_layout=True)
# Out:
# He-ploc.psp8 does not have gbrv_bcc
# He-ploc.psp8 does not have gbrv_fcc
# He.psp8 does not have gbrv_bcc
# He.psp8 does not have gbrv_fcc
# O-dmax-nnlcc.psp8 does not have gbrv_bcc
# O-dmax-nnlcc.psp8 does not have gbrv_fcc
# F-dmax.psp8 does not have gbrv_bcc
# F-high-dmax.psp8 does not have gbrv_bcc
# F-high-dmax.psp8 does not have gbrv_fcc
# Ne-nonlcc.psp8 does not have gbrv_bcc
# Ne-nonlcc.psp8 does not have gbrv_fcc
# Ne.psp8 does not have gbrv_bcc
# Ne.psp8 does not have gbrv_fcc
# Al-sp.psp8 does not have gbrv_bcc
# P-dloc-2.psp8 does not have gbrv_bcc
# P-dloc-2.psp8 does not have gbrv_fcc
# Ar.psp8 does not have gbrv_bcc
# Ar.psp8 does not have gbrv_fcc
# Cr-sp-high-2.psp8 does not have gbrv_bcc
# Cr-sp-high-2.psp8 does not have gbrv_fcc
# Mn-sp-high-2.psp8 does not have gbrv_bcc
# Mn-sp-high-2.psp8 does not have gbrv_fcc
# Fe-sp-high-ncon3-2.psp8 does not have gbrv_bcc
# Fe-sp-high-ncon3-2.psp8 does not have gbrv_fcc
# Co-sp-2.psp8 does not have gbrv_bcc
# ...

# %%
from pseudo_dojo.dojo.gbrv_outdb import GbrvOutdb

data_rock = GbrvOutdb.from_file("rocksalt.json").get_dataframe()
data_abo3 = GbrvOutdb.from_file("ABO3.json").get_dataframe()

# %%
fig = data_rock.plot_hist()

# %%
fig = data_abo3.plot_hist()

# %%
from pandas import concat
alldata = concat([data_rock, data_abo3])
#alldata[["formula", "high_rel_err", "struct_type", "basenames"]]

# %%
for symbol in alldata.symbols:
    fig = alldata.stripplot_symbol(symbol, tight_layout=True)
