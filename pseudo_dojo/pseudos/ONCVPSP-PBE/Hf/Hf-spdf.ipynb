# %% [markdown]
# # This is an auto-generated notebook for Hf-spdf.psp8

# %%
from __future__ import print_function
import mpld3
from mpld3 import plugins as plugs
plugs.DEFAULT_PLUGINS = [plugs.Reset(), plugs.Zoom(), plugs.BoxZoom(), plugs.MousePosition()]
mpld3.enable_notebook()
import seaborn as sns
#sns.set(style="dark", palette="Set2")
sns.set(style='ticks', palette='Set2')

# %%
# Construct the pseudo object and get the DojoReport
from pymatgen.io.abinitio.pseudos import Pseudo
pseudo = Pseudo.from_file('Hf-spdf.psp8')
report = pseudo.dojo_report

# %% [markdown]
# # ONCVPSP Input File:

# %%
input_file = pseudo.filepath.replace(".psp8", ".in") 
with open(input_file, "rt") as fh:
    for line in fh: print(line, end="")
# Out:
# # atsym z nc nv iexc psfile
# Hf 72 9 5 4 psp8
# # n l f
# 1 0 2.0
# 2 0 2.0
# 2 1 6.0
# 3 0 2.0
# 3 1 6.0
# 3 2 10.0
# 4 0 2.0
# 4 1 6.0
# 4 2 10.0
# 5 0 2.0
# 5 1 6.0
# 4 3 14.0
# 5 2 2.0
# 6 0 2.0
# # lmax
# 3
# # l rc ep ncon nbas qcut
# 0 1.55 0.0 4 8 7.5
# 1 1.6 0.0 4 8 8.0
# 2 1.4 0.0 4 8 9.2
# 3 1.6 0.0 4 8 11.4
# # lloc lpopt rc5 dvloc0
# 4 5 1.3 0.0
# # l nproj debl
# 0 2 1.0
# 1 2 1.0
# 2 2 1.0
# 3 2 1.5
# # icmod fcfact
# 1 0.15
# # epsh1 epsh2 depsh
# -12.0 12.0 0.02
# # rlmax drl
# 6.0 0.01
#  0

# %%
# Get data from the output file
from pseudo_dojo.ppcodes.oncvpsp import OncvOutputParser, PseudoGenDataPlotter
onc_parser = OncvOutputParser(pseudo.filepath.replace(".psp8", ".out"))
# Parse the file and build the plotter
onc_parser.scan()
plotter = onc_parser.make_plotter()

# %% [markdown]
# # AE/PS radial wavefunctions $\phi(r)$:

# %%
plotter.plot_radial_wfs(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78845843625121806318250"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78845843625121806318250", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884614250896"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el7884614252432"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884613803472"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7884613933520"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el7884613896464"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171713], "rotation": -0.0, "id": "el7884613749648"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el7884613789904"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el7884613907024"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595956], "rotation": -0.0, "id": "el7884613909200"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404044], "rotation": -0.0, "id": "el7884613915728"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.68371212121212133], "rotation": -0.0, "id": "el7884613918096"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.63952020202020199], "rotation": -0.0, "id": "el7884613924624"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.59532828282828276], "rotation": -0.0, "id": "el7884614252368"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.55113636363636365], "rotation": -0.0, "id": "el7884613926288"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-1.0, 1.5], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "e ...

# %% [markdown]
# # Arctan of the logarithmic derivatives:

# %%
plotter.plot_atan_logders(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el7884613934160136358554"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el7884613934160136358554", {"axes": [{"xlim": [-15.0, 15.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Energy [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884994675472"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(LogDer)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.063791582661290328, 0.5], "rotation": -90.0, "id": "el7884998746000"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(Log Derivative)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884614360144"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7884940758160"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el7884614469456"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171713], "rotation": -0.0, "id": "el7884614475920"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el7884994533840"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el7884994676560"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595956], "rotation": -0.0, "id": "el7884613940560"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404044], "rotation": -0.0, "id": "el7884614478992"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.68371212121212133], "rotation": -0.0, "id": "el7884614497808"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.63952020202020199], "rotation": -0.0, "id": "el7884614500176"}], "zoomable": true, "images": [], "xdomain": [-15.0, 15.0], "ylim": [-5.0, 20.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7884614469008"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#FF0000" ...

# %% [markdown]
# # Convergence in $G$-space estimated by ONCVPSP:

# %%
plotter.plot_ene_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78849658857121167036905"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78849658857121167036905", {"axes": [{"xlim": [0.0, 70.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884940656848"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el7884614232912"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884614394576"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7884614270416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el7884614285136"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el7884614275216"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el7884614277584"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.81628787878787878], "rotation": -0.0, "id": "el7884614267728"}], "zoomable": true, "images": [], "xdomain": [0.0, 70.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7884614284688"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7884614310352"}, {"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 2, "data": "data01", "id": "el7884614310992"}, {"color": "#008000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 3, "linewidth": 2, "data": "data01", "id": "el7884614300496"}, {"color": "#FFA500", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 4, "linewidth": 2, "data": "data01", "id": "el7884614302096"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el7884614285968"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linew ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el78849658857121167036905", {"axes": [{"xlim": [0.0, 70.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884940656848"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el7884614232912"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884614394576"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7884614270416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el7884614285136"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el788461427

# %% [markdown]
# # Projectors:

# %%
plotter.plot_projectors(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78849606680487043650553"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78849606680487043650553", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884613707280"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$p(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el7884613675600"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Projector Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7885017648208"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7884999320592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.94886363636363646], "rotation": -0.0, "id": "el7885017638928"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.90467171717171713], "rotation": -0.0, "id": "el7884999315792"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.86047979797979812], "rotation": -0.0, "id": "el7884999318160"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.8162878787878789], "rotation": -0.0, "id": "el7884999319504"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.77209595959595956], "rotation": -0.0, "id": "el7884999321936"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.72790404040404044], "rotation": -0.0, "id": "el7884999332560"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.68371212121212133], "rotation": -0.0, "id": "el7884999334928"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.63952020202020199], "rotation": -0.0, "id": "el7884999341456"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-1.0, 1.5], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7885017638480"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickv ...

# %% [markdown]
# # Core/Valence/Model charge densities:

# %%
plotter.plot_densities(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78849993175206985572319"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78849993175206985572319", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885017769040"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$n(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.07639238911290322, 0.5], "rotation": -90.0, "id": "el7885017537232"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Charge densities", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884999478352"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885022291664"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoC", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.94886363636363646], "rotation": -0.0, "id": "el7885022271952"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoV", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.90467171717171713], "rotation": -0.0, "id": "el7885022278416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoM", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.86047979797979812], "rotation": -0.0, "id": "el7885022280784"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [0.0, 300.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7885022271504"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885022262160"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885022262800"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885022264400"}, {"color": "#66C2A5", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el7885022272784"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el7885022279312"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el7885022281680"}], "markers": [], "id": "el7884999403664", "ydomain": [0.0, 300.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": " ...

# %% [markdown]
# # Local potential and $l$-dependent potentials:

# %%
plotter.plot_potentials(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78846139342243906377121"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78846139342243906377121", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885022292368"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$v_l(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el7885022431184"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7884999492944"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885028254416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.2108585858585858], "rotation": -0.0, "id": "el7885028226960"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.16666666666666663], "rotation": -0.0, "id": "el7885028233424"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.12247474747474742], "rotation": -0.0, "id": "el7885028235792"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.078282828282828273], "rotation": -0.0, "id": "el7885028234512"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.034090909090909019], "rotation": -0.0, "id": "el7885028247504"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-60.0, 10.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7885028226512"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028205584"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028206224"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028207952"}, {"color": "#FFA500", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028217808"}, {"color": "#000000", "yindex": 5, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "al ...

# %% [markdown]
# # 1-st order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=1, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850282563363041337838"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850282563363041337838", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885022430672"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^1 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.088961693548387094, 0.5], "rotation": -90.0, "id": "el7885028334672"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7885022392144"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885028615056"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el7885028584016"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el7885028598672"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el7885028601040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el7885028603472"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "1-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.77209595959595956], "rotation": -0.0, "id": "el7885028605840"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-120.0, 60.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7885028583568"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028517648"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028517456"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885028518224"}, {"color": "#FFA500", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data0 ...

# %% [markdown]
# # 2-nd order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=2, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850285764642174328915"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850285764642174328915", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885028625488"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^2 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.1015625, 0.5], "rotation": -90.0, "id": "el7885028711696"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el7885028343888"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885033952528"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el7885033917392"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el7885033932048"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el7885033934416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=3", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el7885033945040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "2-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.77209595959595956], "rotation": -0.0, "id": "el7885033951568"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-1200.0, 400.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el7885033916944"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885033830544"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885033830352"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el7885033831120"}, {"color": "#FFA500", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id":  ...

# %% [markdown]
# # Convergence of the total energy:

# %%
# Convergence of the total energy (computed from the deltafactor runs with Wien2K equilibrium volume)
report.plot_etotal_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850282551201798265292"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850282551201798265292", {"axes": [{"xlim": [63.0, 75.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885028528336"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el7885034010064"}], "zoomable": true, "images": [], "xdomain": [63.0, 75.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [64.0, 66.0, 68.0, 70.0, 72.0, 74.0, 84.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el7884994772752"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7884994772752pts"}], "id": "el7885033973456", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[64.0, 1.7857203362509608], [66.0, 0.7953689666464925], [68.0, 0.6791878491640091], [70.0, 0.3303708294406533], [72.0, 0.18274721037596464], [74.0, 0.12506905011832714], [84.0, 0.0]]}, "id": "el7885028255120"});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el78850282551201798265292", {"axes": [{"xlim": [63.0, 75.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885028528336"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el7885034010064"}], "zoomable": true, "images": [], "xdomain": [63.0, 75.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [64.0, 66.0, 68.0, 70.0, 72.0, 74.0, 84.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el7884994772752"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7884994772752pts"}], "id": "el7885033973456", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[64.0, 1.7857203362509608], [66.0, 0.7953689666464925], [68.0, 0.6791878491640091], [70.0, 0.3303708294406533], [72.0, 0.18274721037596464], [74.0, 0.12506905011832714], [84.0, 0.0]]}, "id": "el7885028255120"});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#                  mpld3.draw_figure("fig_el78850282551201798265292", {"axes": [{"xlim": [63.0, 75.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885028528336"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el7885034010064"}], "zoomable": true, "images": [], "xdomain": [63.0, 75.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [64.0, 66.0, 68.0, 70.0, 72.0, 74.0, 84.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el7884994772752"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7884994772752pts"}], "id": "el7885033973456", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true,

# %% [markdown]
# # Convergence of the deltafactor results:

# %%
report.plot_deltafactor_convergence(what=("dfact_meV", "dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78849948559524045731955"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78849948559524045731955", {"axes": [{"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfact_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08240927419354839, 0.5], "rotation": -90.0, "id": "el7884994957584"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [0.20000000000000001, 0.5], "paths": [], "sharey": [], "sharex": ["el7885037163792"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885040027472"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7885040027472pts"}], "id": "el7884994816720", "ydomain": [0.20000000000000001, 0.5], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el7885037265744"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfactprime_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08240927419354839, 0.5], "rotation": -90.0, "id": "el7885037285840"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [0.25, 0.69999999999999996], "paths": [], "sharey": [], "sharex": ["el7884994816720"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885040029008"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, ...

# %% [markdown]
# # Convergence of $\Delta v_0$, $\Delta b_0$, and $\Delta b_1$ (deltafactor tests)

# %%
# Here we plot the difference wrt Wien2k results.
report.plot_deltafactor_convergence(what=("-dfact_meV", "-dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850338729762466015008"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850338729762466015008", {"axes": [{"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$v0", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.095010080645161282, 0.50000000000000044], "rotation": -90.0, "id": "el7885040136080"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [0.0080000000000000002, 0.024], "paths": [], "sharey": [], "sharex": ["el7885040308944", "el7884994791696"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885040380752"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7885040380752pts"}], "id": "el7885037218064", "ydomain": [0.0080000000000000002, 0.024], "collections": [], "xscale": "linear", "bbox": [0.125, 0.66470588235294115, 0.77500000000000002, 0.23529411764705888]}, {"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$b0_GPa", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el7885040336720"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [-1.4000000000000001, 0.19999999999999996], "paths": [], "sharey": [], "sharex": ["el7885037218064", "el7884994791696"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885040381136"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341 ...

# %% [markdown]
# # deltafactor EOS for the different cutoff energies:

# %%
report.plot_deltafactor_eos(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850338643365165141901"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850338643365165141901", {"axes": [{"xlim": [20.5, 24.5], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7884969959952"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.095262096774193547, 0.5], "rotation": -90.0, "id": "el7885017582672"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885045836176"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 64.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.88810483870967738, 0.94886363636363646], "rotation": -0.0, "id": "el7885045890064"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 68.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.88810483870967738, 0.90467171717171713], "rotation": -0.0, "id": "el7885045855632"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 72.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.88810483870967738, 0.86047979797979812], "rotation": -0.0, "id": "el7885045858000"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 84.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.88810483870967738, 0.81628787878787878], "rotation": -0.0, "id": "el7885045856592"}], "zoomable": true, "images": [], "xdomain": [20.5, 24.5], "ylim": [-7879.4000000000005, -7879.3400000000001], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data04", "id": "el7885045889296"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885036918480"}, {"color": "#0010FF", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885036924112"}, {"color": "#00A4FF", "yindex": 3, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885036928208"}, {"color": "#3FFFB7", "yindex": 4, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885037006544"}, {"color": "#B7FF3F", "yindex": 5, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885036945104"}, {"color": "#FFB900", "yindex": 6, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885037057680"}, {"color": "#FF3000", "yindex": 7, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885037051664"} ...

# %% [markdown]
# # Convergence of the GBRV lattice parameters:

# %%
report.plot_gbrv_convergence(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850369039527992354556"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850369039527992354556", {"axes": [{"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el7885040437968"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [-0.048000000000000001, -0.029999999999999999], "paths": [], "sharey": [], "sharex": ["el7885036886288"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885045950416"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el7885045950416pts"}], "id": "el7885037029968", "ydomain": [-0.048000000000000001, -0.029999999999999999], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el7885036828496"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_bcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el7885036811728"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [-0.074999999999999997, -0.029999999999999999], "paths": [], "sharey": [], "sharex": ["el7885037029968"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885045950800"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el78850369039527992354556", {"axes": [{"xlim": [60.0, 85.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el7885040437968"}], "zoomable": true, "images": [], "xdomain": [60.0, 85.0], "ylim": [-0.048000000000000001, -0.029999999999999999], "paths": [], "sharey": [], "sharex": ["el7885036886288"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el7885045950416"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.

# %% [markdown]
# # GBRV EOS for the FCC structure:

# %%
report.plot_gbrv_eos(struct_type="fcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850459584805652290717"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850459584805652290717", {"axes": [{"xlim": [22.0, 23.199999999999999], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885046483728"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el7884969885392"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885055759504"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 64.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el7885050760528"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 68.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474747], "rotation": -0.0, "id": "el7885050771152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 72.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el7885055758416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 84.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909102], "rotation": -0.0, "id": "el7885055760784"}], "zoomable": true, "images": [], "xdomain": [22.0, 23.199999999999999], "ylim": [-7879.2960000000003, -7879.2915000000003], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el7885050759760"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885050603472"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el7885050631120"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data06", "id": "el7885050642192"}, {"color": "#3FFFB7", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data08", "id": "el7885050666960"}, {"color": "#B7FF3F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data10", "id": "el7885050691344"}, {"color": "#FFB900", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data12", "id": "el7885050664656"}, {"color": "#FF3000", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": " ...

# %% [markdown]
# # GBRV EOS for the BCC structure:

# %%
report.plot_gbrv_eos(struct_type="bcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el78850507722401057404343"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el78850507722401057404343", {"axes": [{"xlim": [21.800000000000001, 23.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el7885050663568"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el7885050640976"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el7885055846160"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 64.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el7885055924880"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 68.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474747], "rotation": -0.0, "id": "el7885050640208"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 72.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el7885055832848"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 84.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909102], "rotation": -0.0, "id": "el7885055835216"}], "zoomable": true, "images": [], "xdomain": [21.800000000000001, 23.0], "ylim": [-7879.1980000000003, -7879.1930000000002], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el7885050572304"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el7885050563152"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el7885055972432"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data06", "id": "el7885055926160"}, {"color": "#3FFFB7", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data08", "id": "el7885055988432"}, {"color": "#B7FF3F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data10", "id": "el7885055959504"}, {"color": "#FFB900", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data12", "id": "el7885055919504"}, {"color": "#FF3000", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": " ...
