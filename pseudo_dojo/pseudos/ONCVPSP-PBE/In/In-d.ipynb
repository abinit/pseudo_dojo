# %% [markdown]
# # This is an auto-generated notebook for In-d.psp8

# %%
from __future__ import print_function
import mpld3
from mpld3 import plugins as plugs
plugs.DEFAULT_PLUGINS = [plugs.Reset(), plugs.Zoom(), plugs.BoxZoom(), plugs.MousePosition()]
mpld3.enable_notebook()
import seaborn as sns
#sns.set(style="dark", palette="Set2")
sns.set(style='ticks', palette='Set2')

# %%
# Construct the pseudo object and get the DojoReport
from pymatgen.io.abinitio.pseudos import Pseudo
pseudo = Pseudo.from_file('In-d.psp8')
report = pseudo.dojo_report

# %% [markdown]
# # ONCVPSP Input File:

# %%
input_file = pseudo.filepath.replace(".psp8", ".in") 
# %cat $input_file
# Out:
# # atsym z nc nv iexc psfile
# In 49 8 3 4 psp8
# # n l f
# 1 0 2.0
# 2 0 2.0
# 2 1 6.0
# 3 0 2.0
# 3 1 6.0
# 3 2 10.0
# 4 0 2.0
# 4 1 6.0
# 4 2 10.0
# 5 0 2.0
# 5 1 1.0
# # lmax
# 2
# # l rc ep ncon nbas qcut
# 0 2.1 0.0 5 8 2.8
# 1 2.35 0.0 5 8 2.8
# 2 1.85 0.0 4 7 8.2
# # lloc lpopt rc5 dvloc0
# 4 5 1.7 0.0
# # l nproj debl
# 0 2 1.1
# 1 2 3.0
# 2 2 1.5
# # icmod fcfact
# 1 1.0
# # epsh1 epsh2 depsh
# -12.0 12.0 0.02
# # rlmax drl
# 6.0 0.01
#  0

# %%
# Get data from the output file
from pseudo_dojo.ppcodes.oncvpsp import OncvOutputParser, PseudoGenDataPlotter
onc_parser = OncvOutputParser(pseudo.filepath.replace(".psp8", ".out"))
# Parse the file and build the plotter
onc_parser.scan()
plotter = onc_parser.make_plotter()

# %% [markdown]
# # AE/PS radial wavefunctions $\phi(r)$:

# %%
plotter.plot_radial_wfs(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149846134933288846976054"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149846134933288846976054", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984616728208"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el14984616772880"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984616856272"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984886841168"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el14984616771792"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171735], "rotation": -0.0, "id": "el14984886802064"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el14984886820880"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el14984886823312"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595978], "rotation": -0.0, "id": "el14984886825680"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404055], "rotation": -0.0, "id": "el14984886826000"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-0.60000000000000009, 1.2], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984616772368"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984886790288"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984886790928"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984886 ...

# %% [markdown]
# # Arctan of the logarithmic derivatives:

# %%
plotter.plot_atan_logders(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149848869609122234996248"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149848869609122234996248", {"axes": [{"xlim": [-15.0, 15.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Energy [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984886938576"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(LogDer)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.063791582661290328, 0.5], "rotation": -90.0, "id": "el14984886917712"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(Log Derivative)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984887221840"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984887264592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el14984886999760"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171735], "rotation": -0.0, "id": "el14984886921104"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el14984886941584"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el14984887254672"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595978], "rotation": -0.0, "id": "el14984887257040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404055], "rotation": -0.0, "id": "el14984887263568"}], "zoomable": true, "images": [], "xdomain": [-15.0, 15.0], "ylim": [-5.0, 20.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984887001808"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984887034384"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984887035024"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el149848 ...

# %% [markdown]
# # Convergence in $G$-space estimated by ONCVPSP:

# %%
plotter.plot_ene_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149848872564001379549151"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149848872564001379549151", {"axes": [{"xlim": [0.0, 35.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924542608"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el14984924577808"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984924618320"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984930498192"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el14984930503120"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el14984930505424"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el14984930495568"}], "zoomable": true, "images": [], "xdomain": [0.0, 35.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984930523088"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930534032"}, {"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 2, "data": "data01", "id": "el14984930534672"}, {"color": "#008000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 3, "linewidth": 2, "data": "data01", "id": "el14984930520080"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930503952"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930506320"}, {"color": "#008000", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930496464"}], "markers": [], "id": "el14984924535248", "ydomain": [1.0000000000000001e-05, 0.01], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el149848872564001379549151", {"axes": [{"xlim": [0.0, 35.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924542608"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el14984924577808"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984924618320"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984930498192"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el14984930503120"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el14984930505424"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el14984930495568"}], "zoomable": true, "images": [], "xdomain": [0.0, 35.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984930523088"}], "sharey": [], "sharex": [], "axesbgalpha": null

# %% [markdown]
# # Projectors:

# %%
plotter.plot_projectors(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849304714408589133139"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849304714408589133139", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984930568912"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$p(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el14984930682576"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Projector Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984931088592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984924154768"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.94886363636363646], "rotation": -0.0, "id": "el14984924178896"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.90467171717171735], "rotation": -0.0, "id": "el14984924181200"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.86047979797979812], "rotation": -0.0, "id": "el14984924195920"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.8162878787878789], "rotation": -0.0, "id": "el14984924198288"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.77209595959595978], "rotation": -0.0, "id": "el14984924217104"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.72790404040404055], "rotation": -0.0, "id": "el14984924217424"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-1.0, 1.5], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984931055568"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984931233744"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984931234384"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "d ...

# %% [markdown]
# # Core/Valence/Model charge densities:

# %%
plotter.plot_densities(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849241554724691003943"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849241554724691003943", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984931049040"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$n(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.064138104838709672, 0.5], "rotation": -90.0, "id": "el14984924351376"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Charge densities", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984924325712"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984930857552"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoC", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.94886363636363646], "rotation": -0.0, "id": "el14984930833744"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoV", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.90467171717171713], "rotation": -0.0, "id": "el14984930823824"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoM", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.86047979797979812], "rotation": -0.0, "id": "el14984930826192"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [0.0, 70.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984930833296"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930840208"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930840848"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930842576"}, {"color": "#66C2A5", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930822352"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930824720"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930855824"}], "markers": [], "id": "el14984924136400", "ydomain": [0.0, 70.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugin ...

# %% [markdown]
# # Local potential and $l$-dependent potentials:

# %%
plotter.plot_potentials(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849308103209044981541"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849308103209044981541", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924296912"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$v_l(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el14984924368720"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984930951824"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984924850896"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el14984930739216"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171713], "rotation": -0.0, "id": "el14984924876112"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el14984924878480"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.81628787878787878], "rotation": -0.0, "id": "el14984924860432"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-25.0, 10.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984930738768"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930760400"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930748816"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930750544"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984930752144"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984930740048"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "dat ...

# %% [markdown]
# # 1-st order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=1, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849248231201489945076"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849248231201489945076", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984925019536"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^1 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el14984924985040"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984924832016"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984944236944"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el14984944280272"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el14984944253968"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el14984944256336"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "1-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el14984944275152"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-40.0, 20.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984944279824"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984924886544"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984924886352"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984924891216"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984924892944"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984944281104"}, {"color": "#0000FF", "yindex": 2, "coordinates":  ...

# %% [markdown]
# # 2-nd order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=2, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849442726566685998532"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849442726566685998532", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984944371472"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^2 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.088961693548387094, 0.5], "rotation": -90.0, "id": "el14984924346896"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el14984944395408"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984963386640"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el14984963380816"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el14984963391376"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el14984963361040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "2-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el14984963363408"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-300.0, 100.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el14984963380368"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984944290192"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984944290000"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984944290768"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el14984944292496"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el14984963389904"}, {"color": "#0000FF", "yindex": 2, "coordinates" ...

# %% [markdown]
# # Convergence of the total energy:

# %%
# Convergence of the total energy (computed from the deltafactor runs with Wien2K equilibrium volume)
report.plot_etotal_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849634903841195600501"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849634903841195600501", {"axes": [{"xlim": [32.0, 44.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924354000"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el14984963344464"}], "zoomable": true, "images": [], "xdomain": [32.0, 44.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [33.0, 35.0, 37.0, 39.0, 41.0, 43.0, 53.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el14984963319696"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984963319696pts"}], "id": "el14984963488464", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[33.0, 2.107461667386815], [35.0, 0.7130651334300637], [37.0, 0.6641394309699535], [39.0, 0.49482846236787736], [41.0, 0.3587127272039652], [43.0, 0.29375255946069956], [53.0, 0.0]]}, "id": "el14984963490384"});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el149849634903841195600501", {"axes": [{"xlim": [32.0, 44.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924354000"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el14984963344464"}], "zoomable": true, "images": [], "xdomain": [32.0, 44.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [33.0, 35.0, 37.0, 39.0, 41.0, 43.0, 53.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el14984963319696"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984963319696pts"}], "id": "el14984963488464", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[33.0, 2.107461667386815], [35.0, 0.7130651334300637], [37.0, 0.6641394309699535], [39.0, 0.49482846236787736], [41.0, 0.3587127272039652], [43.0, 0.29375255946069956], [53.0, 0.0]]}, "id": "el14984963490384"});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#                  mpld3.draw_figure("fig_el149849634903841195600501", {"axes": [{"xlim": [32.0, 44.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984924354000"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el14984963344464"}], "zoomable": true, "images": [], "xdomain": [32.0, 44.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [33.0, 35.0, 37.0, 39.0, 41.0, 43.0, 53.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el14984963319696"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984963319696pts"}], "id": "el14984963488464", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": fals

# %% [markdown]
# # Convergence of the deltafactor results:

# %%
report.plot_deltafactor_convergence(what=("dfact_meV", "dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849634109603416266147"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849634109603416266147", {"axes": [{"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfact_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.095010080645161282, 0.5], "rotation": -90.0, "id": "el14984967262480"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [0.050000000000000003, 0.085000000000000006], "paths": [], "sharey": [], "sharex": ["el14984967876368"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984968035920"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984968035920pts"}], "id": "el14984963699600", "ydomain": [0.050000000000000003, 0.085000000000000006], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el14984967888208"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfactprime_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08240927419354839, 0.5], "rotation": -90.0, "id": "el14984967908304"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [0.0, 0.45000000000000001], "paths": [], "sharey": [], "sharex": ["el14984963699600"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984968036304"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.474873734152 ...

# %% [markdown]
# # Convergence of $\Delta v_0$, $\Delta b_0$, and $\Delta b_1$ (deltafactor tests)

# %%
# Here we plot the difference wrt Wien2k results.
report.plot_deltafactor_convergence(what=("-dfact_meV", "-dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849637076009416415748"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849637076009416415748", {"axes": [{"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$v0", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.50000000000000044], "rotation": -90.0, "id": "el14984967369680"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [-0.016, -0.002], "paths": [], "sharey": [], "sharex": ["el14984980540432", "el14984992356816"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984992500688"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984992500688pts"}], "id": "el14984924980368", "ydomain": [-0.016, -0.002], "collections": [], "xscale": "linear", "bbox": [0.125, 0.66470588235294115, 0.77500000000000002, 0.23529411764705888]}, {"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$b0_GPa", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08240927419354839, 0.5], "rotation": -90.0, "id": "el14984980411216"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [0.050000000000000003, 0.35000000000000003], "paths": [], "sharey": [], "sharex": ["el14984924980368", "el14984992356816"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984992502160"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295 ...

# %% [markdown]
# # deltafactor EOS for the different cutoff energies:

# %%
report.plot_deltafactor_eos(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849680362402465300586"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849680362402465300586", {"axes": [{"xlim": [25.5, 29.5], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984980398288"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el14984968087824"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984993198480"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 33.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2992424242424242], "rotation": -0.0, "id": "el14984993169808"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 35.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.25505050505050503], "rotation": -0.0, "id": "el14984993141776"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 37.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2108585858585858], "rotation": -0.0, "id": "el14984993237456"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el14984993239504"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474742], "rotation": -0.0, "id": "el14984993176400"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el14984993178768"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 53.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909075], "rotation": -0.0, "id": "el14984993197584"}], "zoomable": true, "images": [], "xdomain": [25.5, 29.5], "ylim": [-1809.155, -1809.135], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data04", "id": "el14984993169040"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el14984571355728"}, {"color": "#0010FF", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el14984980370768"}, {"color": "#00A4FF", "yindex": 3, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": ...

# %% [markdown]
# # Convergence of the GBRV lattice parameters:

# %%
report.plot_gbrv_convergence(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849925794083036202141"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849925794083036202141", {"axes": [{"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el14984993083088"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [-0.108, -0.094], "paths": [], "sharey": [], "sharex": ["el14984571320208"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984995584912"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el14984995584912pts"}], "id": "el14984993039184", "ydomain": [-0.108, -0.094], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el14984571332048"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_bcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el14984571475024"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [-0.112, -0.106], "paths": [], "sharey": [], "sharex": ["el14984993039184"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984995585296"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.818529 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el149849925794083036202141", {"axes": [{"xlim": [30.0, 55.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el14984993083088"}], "zoomable": true, "images": [], "xdomain": [30.0, 55.0], "ylim": [-0.108, -0.094], "paths": [], "sharey": [], "sharex": ["el14984571320208"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el14984995584912"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.818529547746

# %% [markdown]
# # GBRV EOS for the FCC structure:

# %%
report.plot_gbrv_eos(struct_type="fcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el149849956295847411886587"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el149849956295847411886587", {"axes": [{"xlim": [26.800000000000001, 28.199999999999999], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984995552336"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.12046370967741934, 0.5], "rotation": -90.0, "id": "el14984995539280"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14984999237456"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 33.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.94886363636363646], "rotation": -0.0, "id": "el14984999205328"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 35.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.90467171717171713], "rotation": -0.0, "id": "el14984999207696"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 37.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.86047979797979812], "rotation": -0.0, "id": "el14984999161168"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.81628787878787878], "rotation": -0.0, "id": "el14984999215056"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.77209595959595956], "rotation": -0.0, "id": "el14984999221584"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.72790404040404044], "rotation": -0.0, "id": "el14984999223952"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 53.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.68371212121212133], "rotation": -0.0, "id": "el14984999234576"}], "zoomable": true, "images": [], "xdomain": [26.800000000000001, 28.199999999999999], "ylim": [-1809.1244999999999, -1809.1205], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el14984999188112"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el14984963708176"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el14984995841872"}, {"color": "#00A4FF", "yindex": 1, "coordinates": " ...

# %% [markdown]
# # GBRV EOS for the BCC structure:

# %%
report.plot_gbrv_eos(struct_type="bcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el14984999216016117230479"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el14984999216016117230479", {"axes": [{"xlim": [27.200000000000003, 28.600000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el14984999063824"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.12046370967741934, 0.5], "rotation": -90.0, "id": "el14984999066192"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el14985003134288"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 33.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.94886363636363646], "rotation": -0.0, "id": "el14985003094160"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 35.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.90467171717171713], "rotation": -0.0, "id": "el14985003104784"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 37.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.86047979797979812], "rotation": -0.0, "id": "el14985003107152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.81628787878787878], "rotation": -0.0, "id": "el14985003105872"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.77209595959595956], "rotation": -0.0, "id": "el14985003118352"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.72790404040404044], "rotation": -0.0, "id": "el14985003124880"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 53.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.68371212121212133], "rotation": -0.0, "id": "el14985003127248"}], "zoomable": true, "images": [], "xdomain": [27.200000000000003, 28.600000000000001], "ylim": [-1809.1165000000001, -1809.1125], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el14985003093392"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el14984995975504"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el14985002969936"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "d ...

# %% [markdown]
# # Comparison with the other pseudos in this table

# %%
from pseudo_dojo import get_pseudos
pseudos = get_pseudos(".")
if len(pseudos) > 1:
    pseudos.dojo_compare()
