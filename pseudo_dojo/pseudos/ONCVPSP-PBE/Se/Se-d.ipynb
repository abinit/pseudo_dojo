# %% [markdown]
# # This is an auto-generated notebook for Se-d.psp8

# %%
from __future__ import print_function
import mpld3
from mpld3 import plugins as plugs
plugs.DEFAULT_PLUGINS = [plugs.Reset(), plugs.Zoom(), plugs.BoxZoom(), plugs.MousePosition()]
mpld3.enable_notebook()
import seaborn as sns
#sns.set(style="dark", palette="Set2")
sns.set(style='ticks', palette='Set2')

# %%
# Construct the pseudo object and get the DojoReport
from pymatgen.io.abinitio.pseudos import Pseudo
pseudo = Pseudo.from_file('Se-d.psp8')
report = pseudo.dojo_report

# %% [markdown]
# # ONCVPSP Input File:

# %%
input_file = pseudo.filepath.replace(".psp8", ".in") 
# %cat $input_file
# Out:
# # atsym z nc nv iexc psfile
# Se 34 5 3 4 psp8
# # n l f
# 1 0 2.0
# 2 0 2.0
# 2 1 6.0
# 3 0 2.0
# 3 1 6.0
# 3 2 10.0
# 4 0 2.0
# 4 1 4.0
# # lmax
# 2
# # l rc ep ncon nbas qcut
# 0 1.8 0.0 4 8 5.4
# 1 1.5 0.0 4 8 7.8
# 2 1.9 0.0 4 9 9.2
# # lloc lpopt rc5 dvloc0
# 4 5 1.5 0.0
# # l nproj debl
# 0 2 4.5
# 1 2 4.5
# 2 2 2.0
# # icmod fcfact
# 1 0.2
# # epsh1 epsh2 depsh
# -12.0 12.0 0.02
# # rlmax drl
# 6.0 0.01
#  0

# %%
# Get data from the output file
from pseudo_dojo.ppcodes.oncvpsp import OncvOutputParser, PseudoGenDataPlotter
onc_parser = OncvOutputParser(pseudo.filepath.replace(".psp8", ".out"))
# Parse the file and build the plotter
onc_parser.scan()
plotter = onc_parser.make_plotter()

# %% [markdown]
# # AE/PS radial wavefunctions $\phi(r)$:

# %%
plotter.plot_radial_wfs(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31946113634083080029173"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31946113634083080029173", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194616764944"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el3194616772752"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194616856144"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194621899472"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el3194616770960"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171735], "rotation": -0.0, "id": "el3194621868560"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el3194621879184"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el3194621881616"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595978], "rotation": -0.0, "id": "el3194621883984"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404055], "rotation": -0.0, "id": "el3194621884304"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-0.5, 1.5], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194616772240"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194621836240"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194621857424"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194621859152"}, {"color": "#0000FF",  ...

# %% [markdown]
# # Arctan of the logarithmic derivatives:

# %%
plotter.plot_atan_logders(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31946220193444343574387"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31946220193444343574387", {"axes": [{"xlim": [-15.0, 15.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Energy [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194621992656"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(LogDer)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.063760080645161282, 0.5], "rotation": -90.0, "id": "el3194621971792"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(Log Derivative)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194935292240"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194935388944"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el3194622057872"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171735], "rotation": -0.0, "id": "el3194621972880"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el3194621995792"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el3194935378320"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595978], "rotation": -0.0, "id": "el3194935380688"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404055], "rotation": -0.0, "id": "el3194935387216"}], "zoomable": true, "images": [], "xdomain": [-15.0, 15.0], "ylim": [-5.0, 15.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194622059920"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194935153936"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194935154576"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194935299728"}, {"c ...

# %% [markdown]
# # Convergence in $G$-space estimated by ONCVPSP:

# %%
plotter.plot_ene_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949353790886261129754"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949353790886261129754", {"axes": [{"xlim": [0.0, 40.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194936934160"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el3194936940624"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194936985232"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194937384720"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el3194937405968"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el3194937408272"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el3194937390224"}], "zoomable": true, "images": [], "xdomain": [0.0, 40.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194937405520"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937023184"}, {"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 2, "data": "data01", "id": "el3194937408912"}, {"color": "#008000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 3, "linewidth": 2, "data": "data01", "id": "el3194937410640"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937406800"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937388752"}, {"color": "#008000", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937391120"}], "markers": [], "id": "el3194936916176", "ydomain": [1.0000000000000001e-05, 0.01], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.800000000000 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el31949353790886261129754", {"axes": [{"xlim": [0.0, 40.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194936934160"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el3194936940624"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194936985232"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194937384720"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el3194937405968"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el3194937408272"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el3194937390224"}], "zoomable": true, "images": [], "xdomain": [0.0, 40.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194937405520"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear

# %% [markdown]
# # Projectors:

# %%
plotter.plot_projectors(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949373865765768801835"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949373865765768801835", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194937933008"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$p(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el3194937595216"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Projector Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194937902864"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194947971536"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.94886363636363646], "rotation": -0.0, "id": "el3194938054672"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.90467171717171735], "rotation": -0.0, "id": "el3194947891536"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.86047979797979812], "rotation": -0.0, "id": "el3194947893904"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.8162878787878789], "rotation": -0.0, "id": "el3194947949584"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.77209595959595978], "rotation": -0.0, "id": "el3194947968400"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.72790404040404055], "rotation": -0.0, "id": "el3194947968720"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-1.0, 1.5], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194938054224"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194938109520"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194938110160"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01" ...

# %% [markdown]
# # Core/Valence/Model charge densities:

# %%
plotter.plot_densities(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949479577124814874102"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949479577124814874102", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194937909008"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$n(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.074754284274193547, 0.5], "rotation": -90.0, "id": "el3194948090704"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Charge densities", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194948097488"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194937737424"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoC", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.94886363636363646], "rotation": -0.0, "id": "el3194937746384"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoV", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.90467171717171713], "rotation": -0.0, "id": "el3194937711888"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoM", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.86047979797979812], "rotation": -0.0, "id": "el3194937714256"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [0.0, 160.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194937745936"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937720080"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937720720"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937722448"}, {"color": "#66C2A5", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937747216"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937712784"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194937715152"}], "markers": [], "id": "el3194938147536", "ydomain": [0.0, 160.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type":  ...

# %% [markdown]
# # Local potential and $l$-dependent potentials:

# %%
plotter.plot_potentials(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949377381284023052094"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949377381284023052094", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194937851536"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$v_l(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el3194948148944"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194937838096"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194953720400"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el3194953640848"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171713], "rotation": -0.0, "id": "el3194953635024"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el3194953727568"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.81628787878787878], "rotation": -0.0, "id": "el3194953729936"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-40.0, 50.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194953640400"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937626256"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937626896"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194937628624"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194953637456"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194953633552"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "e ...

# %% [markdown]
# # 1-st order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=1, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949538381604313781686"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949538381604313781686", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194937759952"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^1 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.088961693548387094, 0.5], "rotation": -90.0, "id": "el3194953830160"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194953666512"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194954017296"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.16666666666666663], "rotation": -0.0, "id": "el3194953937808"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.12247474747474747], "rotation": -0.0, "id": "el3194953923792"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.078282828282828273], "rotation": -0.0, "id": "el3194953926160"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "1-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.034090909090909102], "rotation": -0.0, "id": "el3194954014608"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-200.0, 50.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194953937360"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194953758352"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194953758160"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194953758928"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194953916368"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194953938640"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "das ...

# %% [markdown]
# # 2-nd order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=2, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949540164007689815060"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949540164007689815060", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194954093264"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^2 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.1015625, 0.5], "rotation": -90.0, "id": "el3194953791760"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el3194954117264"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194962533264"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el3194962515216"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el3194962505296"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el3194962507664"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "2-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el3194962530576"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-3000.0, 1000.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el3194962514768"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194954037264"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194954037072"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194954037840"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el3194954047824"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el3194962516048"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": " ...

# %% [markdown]
# # Convergence of the total energy:

# %%
# Convergence of the total energy (computed from the deltafactor runs with Wien2K equilibrium volume)
report.plot_etotal_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949540494246827325456"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949540494246827325456", {"axes": [{"xlim": [38.0, 50.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194953790096"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el3194962483088"}], "zoomable": true, "images": [], "xdomain": [38.0, 50.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [39.0, 41.0, 43.0, 45.0, 47.0, 49.0, 59.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el3194962546128"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194962546128pts"}], "id": "el3194954157648", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[39.0, 4.882588243577629], [41.0, 0.8202489796094596], [43.0, 0.5649070269428194], [45.0, 0.4760139654390514], [47.0, 0.39251119643449783], [49.0, 0.3215564447455108], [59.0, 0.0]]}, "id": "el3194954049424"});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el31949540494246827325456", {"axes": [{"xlim": [38.0, 50.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194953790096"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el3194962483088"}], "zoomable": true, "images": [], "xdomain": [38.0, 50.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [39.0, 41.0, 43.0, 45.0, 47.0, 49.0, 59.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el3194962546128"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194962546128pts"}], "id": "el3194954157648", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[39.0, 4.882588243577629], [41.0, 0.8202489796094596], [43.0, 0.5649070269428194], [45.0, 0.4760139654390514], [47.0, 0.39251119643449783], [49.0, 0.3215564447455108], [59.0, 0.0]]}, "id": "el3194954049424"});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#                  mpld3.draw_figure("fig_el31949540494246827325456", {"axes": [{"xlim": [38.0, 50.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194953790096"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el3194962483088"}], "zoomable": true, "images": [], "xdomain": [38.0, 50.0], "ylim": [0.10000000000000001, 10.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [39.0, 41.0, 43.0, 45.0, 47.0, 49.0, 59.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 5, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el3194962546128"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194962546128pts"}], "id": "el3194954157648", "ydomain": [0.10000000000000001, 10.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "typ

# %% [markdown]
# # Convergence of the deltafactor results:

# %%
report.plot_deltafactor_convergence(what=("dfact_meV", "dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3194962657104512010945"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el3194962657104512010945", {"axes": [{"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfact_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08240927419354839, 0.5], "rotation": -90.0, "id": "el3194967757392"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [0.050000000000000003, 0.35000000000000003], "paths": [], "sharey": [], "sharex": ["el3194329032080"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194329186448"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194329186448pts"}], "id": "el3194967717136", "ydomain": [0.050000000000000003, 0.35000000000000003], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el3194329039824"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfactprime_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.069808467741935484, 0.5], "rotation": -90.0, "id": "el3194329054288"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [0.10000000000000001, 0.70000000000000007], "paths": [], "sharey": [], "sharex": ["el3194967717136"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194329186576"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341 ...

# %% [markdown]
# # Convergence of $\Delta v_0$, $\Delta b_0$, and $\Delta b_1$ (deltafactor tests)

# %%
# Here we plot the difference wrt Wien2k results.
report.plot_deltafactor_convergence(what=("-dfact_meV", "-dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949678135848596969645"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949678135848596969645", {"axes": [{"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$v0", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.091985887096774188, 0.50000000000000044], "rotation": -90.0, "id": "el3194329058192"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [-0.01, 0.040000000000000001], "paths": [], "sharey": [], "sharex": ["el3194967669648", "el3194967983888"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194971174096"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194971174096pts"}], "id": "el3194937442640", "ydomain": [-0.01, 0.040000000000000001], "collections": [], "xscale": "linear", "bbox": [0.125, 0.66470588235294115, 0.77500000000000002, 0.23529411764705888]}, {"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$b0_GPa", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082440776209677422, 0.5], "rotation": -90.0, "id": "el3194967685200"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [-0.20000000000000001, 1.0000000000000002], "paths": [], "sharey": [], "sharex": ["el3194937442640", "el3194967983888"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194971175248"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529 ...

# %% [markdown]
# # deltafactor EOS for the different cutoff energies:

# %%
report.plot_deltafactor_eos(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31943291746088945928078"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31943291746088945928078", {"axes": [{"xlim": [27.5, 32.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194971250128"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194971278800"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194983490448"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2992424242424242], "rotation": -0.0, "id": "el3194983437968"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.25505050505050503], "rotation": -0.0, "id": "el3194983359056"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2108585858585858], "rotation": -0.0, "id": "el3194983460304"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 45.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el3194983462672"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 47.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474742], "rotation": -0.0, "id": "el3194983481488"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 49.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el3194983483856"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 59.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909075], "rotation": -0.0, "id": "el3194983462032"}], "zoomable": true, "images": [], "xdomain": [27.5, 32.0], "ylim": [-3228.0700000000002, -3228.04], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data04", "id": "el3194983441360"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el3194979428560"}, {"color": "#0010FF", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el3194979449680"}, {"color": "#00A4FF", "yindex": 3, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0,  ...

# %% [markdown]
# # Convergence of the GBRV lattice parameters:

# %%
report.plot_gbrv_convergence(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949712040483229371004"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949712040483229371004", {"axes": [{"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194983346896"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [-0.095000000000000001, -0.070000000000000007], "paths": [], "sharey": [], "sharex": ["el3194979493648"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194987407696"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el3194987407696pts"}], "id": "el3194983429136", "ydomain": [-0.095000000000000001, -0.070000000000000007], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el3194987189584"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_bcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194987287504"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [-0.085000000000000006, -0.060000000000000005], "paths": [], "sharey": [], "sharex": ["el3194983429136"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194987408080"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.13121792 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el31949712040483229371004", {"axes": [{"xlim": [35.0, 60.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194983346896"}], "zoomable": true, "images": [], "xdomain": [35.0, 60.0], "ylim": [-0.095000000000000001, -0.070000000000000007], "paths": [], "sharey": [], "sharex": ["el3194979493648"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el3194987407696"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217

# %% [markdown]
# # GBRV EOS for the FCC structure:

# %%
report.plot_gbrv_eos(struct_type="fcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949794460962498368776"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949794460962498368776", {"axes": [{"xlim": [19.900000000000002, 20.800000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194987273296"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194987265168"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194990837648"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.62405303030303017], "rotation": -0.0, "id": "el3194990789328"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.57986111111111105], "rotation": -0.0, "id": "el3194990804048"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.53566919191919182], "rotation": -0.0, "id": "el3194990770704"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 45.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.49147727272727271], "rotation": -0.0, "id": "el3194990806992"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 47.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.44728535353535348], "rotation": -0.0, "id": "el3194990817616"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 49.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.40309343434343425], "rotation": -0.0, "id": "el3194990819984"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 59.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.35890151515151514], "rotation": -0.0, "id": "el3194990822416"}], "zoomable": true, "images": [], "xdomain": [19.900000000000002, 20.800000000000001], "ylim": [-3227.3560000000002, -3227.3480000000004], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el3194990788560"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el3194983803344"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el3194990663120"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data" ...

# %% [markdown]
# # GBRV EOS for the BCC structure:

# %%
report.plot_gbrv_eos(struct_type="bcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el31949907710247903920944"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el31949907710247903920944", {"axes": [{"xlim": [20.200000000000003, 21.100000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el3194990753488"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el3194990729744"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el3194990670800"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 39.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.62405303030303017], "rotation": -0.0, "id": "el3194994562832"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 41.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.57986111111111105], "rotation": -0.0, "id": "el3194994557008"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 43.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.53566919191919182], "rotation": -0.0, "id": "el3194994543376"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 45.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.49147727272727271], "rotation": -0.0, "id": "el3194994584336"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 47.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.44728535353535348], "rotation": -0.0, "id": "el3194994538832"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 49.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.40309343434343425], "rotation": -0.0, "id": "el3194983626448"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 59.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.35890151515151514], "rotation": -0.0, "id": "el3194983622288"}], "zoomable": true, "images": [], "xdomain": [20.200000000000003, 21.100000000000001], "ylim": [-3227.4209999999998, -3227.413], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el3194994561360"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el3194983661520"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el3194983623056"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data", "dasharr ...

# %% [markdown]
# # Comparison with the other pseudos in this table

# %%
from pseudo_dojo import get_pseudos
pseudos = get_pseudos(".")
if len(pseudos) > 1:
    pseudos.dojo_compare()
