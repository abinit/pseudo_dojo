# %% [markdown]
# # This is an auto-generated notebook for Si.psp8

# %%
from __future__ import print_function
import mpld3
from mpld3 import plugins as plugs
plugs.DEFAULT_PLUGINS = [plugs.Reset(), plugs.Zoom(), plugs.BoxZoom(), plugs.MousePosition()]
mpld3.enable_notebook()
import seaborn as sns
#sns.set(style="dark", palette="Set2")
sns.set(style='ticks', palette='Set2')

# %%
# Construct the pseudo object and get the DojoReport
from pymatgen.io.abinitio.pseudos import Pseudo
pseudo = Pseudo.from_file('Si.psp8')
report = pseudo.dojo_report

# %% [markdown]
# # ONCVPSP Input File:

# %%
input_file = pseudo.filepath.replace(".psp8", ".in") 
# %cat $input_file
# Out:
# # atsym z nc nv iexc psfile
# Si 14 3 2 4 psp8
# # n l f
# 1 0 2.0
# 2 0 2.0
# 2 1 6.0
# 3 0 2.0
# 3 1 2.0
# # lmax
# 2
# # l rc ep ncon nbas qcut
# 0 1.6 0.0 4 9 5.5
# 1 1.71 0.0 4 9 5.6
# 2 1.9 0.05 4 9 5.0
# # lloc lpopt rc5 dvloc0
# 4 5 1.6 0.0
# # l nproj debl
# 0 2 2.5
# 1 2 2.5
# 2 2 1.5
# # icmod fcfact
# 1 0.5
# # epsh1 epsh2 depsh
# -12.0 12.0 0.02
# # rlmax drl
# 6.0 0.01
#  0

# %%
# Get data from the output file
from pseudo_dojo.ppcodes.oncvpsp import OncvOutputParser, PseudoGenDataPlotter
onc_parser = OncvOutputParser(pseudo.filepath.replace(".psp8", ".out"))
# Parse the file and build the plotter
onc_parser.scan()
plotter = onc_parser.make_plotter()

# %% [markdown]
# # AE/PS radial wavefunctions $\phi(r)$:

# %%
plotter.plot_radial_wfs(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82946117503524662341137"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82946117503524662341137", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294612269136"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082566784274193547, 0.5], "rotation": -90.0, "id": "el8294612313808"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294612356176"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294919026576"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.94886363636363646], "rotation": -0.0, "id": "el8294918988688"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.90467171717171735], "rotation": -0.0, "id": "el8294919003344"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.86047979797979812], "rotation": -0.0, "id": "el8294919005776"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.8162878787878789], "rotation": -0.0, "id": "el8294919008144"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.77209595959595978], "rotation": -0.0, "id": "el8294919009040"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.72790404040404055], "rotation": -0.0, "id": "el8294919023696"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-0.40000000000000002, 0.80000000000000016], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294918988240"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294612408784"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294612409424"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el ...

# %% [markdown]
# # Arctan of the logarithmic derivatives:

# %%
plotter.plot_atan_logders(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949190272163972130979"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949190272163972130979", {"axes": [{"xlim": [-15.0, 15.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Energy [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294922162192"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(LogDer)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.063665574596774188, 0.5], "rotation": -90.0, "id": "el8294922190416"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "ATAN(Log Derivative)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294919176784"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294922649680"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el8294922620944"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171735], "rotation": -0.0, "id": "el8294922627408"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el8294922629776"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.8162878787878789], "rotation": -0.0, "id": "el8294922644496"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "AE l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.77209595959595978], "rotation": -0.0, "id": "el8294922646928"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.72790404040404055], "rotation": -0.0, "id": "el8294922649296"}], "zoomable": true, "images": [], "xdomain": [-15.0, 15.0], "ylim": [-4.0, 12.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294922620496"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294919231056"}, {"color": "#FF0000", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294919231696"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294919233424"}, {"c ...

# %% [markdown]
# # Convergence in $G$-space estimated by ONCVPSP:

# %%
plotter.plot_ene_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8294922141392795432812"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el8294922141392795432812", {"axes": [{"xlim": [0.0, 16.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294922672592"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el8294922350480"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294922589072"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294919293072"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el8294922808976"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el8294919280592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el8294919282704"}], "zoomable": true, "images": [], "xdomain": [0.0, 16.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294922808528"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294922794896"}, {"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 2, "data": "data01", "id": "el8294922795536"}, {"color": "#008000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 3, "linewidth": 2, "data": "data01", "id": "el8294922797264"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294922809808"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294919281488"}, {"color": "#008000", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294919283088"}], "markers": [], "id": "el8294922206928", "ydomain": [1.0000000000000001e-05, 0.01], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.8000000000000 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el8294922141392795432812", {"axes": [{"xlim": [0.0, 16.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294922672592"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta E$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082501639089276713, 0.5], "rotation": -90.0, "id": "el8294922350480"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy error per electron [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294922589072"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294919293072"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.94886363636363646], "rotation": -0.0, "id": "el8294922808976"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.90467171717171713], "rotation": -0.0, "id": "el8294919280592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Conv l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.89138104838709686, 0.86047979797979812], "rotation": -0.0, "id": "el8294919282704"}], "zoomable": true, "images": [], "xdomain": [0.0, 16.0], "ylim": [1.0000000000000001e-05, 0.01], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294922808528"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "ti

# %% [markdown]
# # Projectors:

# %%
plotter.plot_projectors(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949227486249319168633"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949227486249319168633", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294929833424"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$p(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el8294929685328"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Projector Wave Functions", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294929689360"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294936383120"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.25505050505050503], "rotation": -0.0, "id": "el8294936394448"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.21085858585858586], "rotation": -0.0, "id": "el8294936396752"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.16666666666666663], "rotation": -0.0, "id": "el8294936390992"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.1224747474747475], "rotation": -0.0, "id": "el8294936364752"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=1, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.078282828282828273], "rotation": -0.0, "id": "el8294936395408"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Proj n=2, l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.85282258064516137, 0.034090909090909102], "rotation": -0.0, "id": "el8294936367952"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-0.80000000000000004, 0.80000000000000004], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294936394000"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929850576"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929851216"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex":  ...

# %% [markdown]
# # Core/Valence/Model charge densities:

# %%
plotter.plot_densities(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949363837603188628090"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949363837603188628090", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294929673040"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$n(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.062153477822580641, 0.5], "rotation": -90.0, "id": "el8294929834640"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Charge densities", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294936337104"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294929516176"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoC", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.94886363636363646], "rotation": -0.0, "id": "el8294929496464"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoV", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.90467171717171713], "rotation": -0.0, "id": "el8294929498768"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "rhoM", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.93170362903225812, 0.86047979797979812], "rotation": -0.0, "id": "el8294929484816"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [0.0, 12.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294929496016"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#66C2A5", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929375888"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929503568"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929505296"}, {"color": "#66C2A5", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294929497296"}, {"color": "#FA8D62", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294929483344"}, {"color": "#8D9FCA", "yindex": 3, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294929485712"}], "markers": [], "id": "el8294936489104", "ydomain": [0.0, 12.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "r ...

# %% [markdown]
# # Local potential and $l$-dependent potentials:

# %%
plotter.plot_potentials(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el8294929516816984626103"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el8294929516816984626103", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294936449808"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$v_l(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el8294929594448"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294929578704"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294939294800"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.94886363636363646], "rotation": -0.0, "id": "el8294939310928"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.90467171717171713], "rotation": -0.0, "id": "el8294939296912"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.86047979797979812], "rotation": -0.0, "id": "el8294939299280"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.91381048387096764, 0.81628787878787878], "rotation": -0.0, "id": "el8294939293520"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-10.0, 20.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294939310480"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929448464"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294929449104"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294939285392"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294939286992"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294939311760"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8 ...

# %% [markdown]
# # 1-st order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=1, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949392965925984145388"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949392965925984145388", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294929535824"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^1 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.076360887096774188, 0.5], "rotation": -90.0, "id": "el8294939520144"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294939318992"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294954994128"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.16666666666666663], "rotation": -0.0, "id": "el8294954968144"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.12247474747474747], "rotation": -0.0, "id": "el8294954970192"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.078282828282828273], "rotation": -0.0, "id": "el8294954980816"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "1-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.034090909090909102], "rotation": -0.0, "id": "el8294954983184"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-40.0, 10.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294954955344"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294954940496"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294954940432"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294954940880"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294954942544"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294954968976"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dash ...

# %% [markdown]
# # 2-nd order derivative of $v_l$ and $v_{loc}$ computed via finite differences:

# %%
plotter.plot_der_potentials(order=2, show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949549524007961600044"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949549524007961600044", {"axes": [{"xlim": [0.0, 6.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "r [Bohr]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294955096784"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$D^2 \\phi(r)$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.088961693548387094, 0.5], "rotation": -90.0, "id": "el8294955078608"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Derivative of the ion Pseudopotentials", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0157828282828283], "rotation": -0.0, "id": "el8294939623952"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294955223696"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.94886363636363646], "rotation": -0.0, "id": "el8294955119568"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=1", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.90467171717171713], "rotation": -0.0, "id": "el8294955240720"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "$s-order derivative PS l=2", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.86047979797979812], "rotation": -0.0, "id": "el8294955259536"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "2-order derivative Vloc", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.72177419354838712, 0.81628787878787878], "rotation": -0.0, "id": "el8294955261904"}], "zoomable": true, "images": [], "xdomain": [0.0, 6.0], "ylim": [-250.0, 100.0], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data03", "id": "el8294955119120"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#FF0000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294955104016"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294955103824"}, {"color": "#008000", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294955104592"}, {"color": "#000000", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data01", "id": "el8294955106320"}, {"color": "#FF0000", "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000002.0, "alpha": 1, "xindex": 0, "linewidth": 2, "data": "data02", "id": "el8294955239248"}, {"color": "#0000FF", "yindex": 2, "coordinates": "axes", "dash ...

# %% [markdown]
# # Convergence of the total energy:

# %%
# Convergence of the total energy (computed from the deltafactor runs with Wien2K equilibrium volume)
report.plot_etotal_vs_ecut(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949392953768576710009"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949392953768576710009", {"axes": [{"xlim": [15.0, 27.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294955145296"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el8294955196752"}], "zoomable": true, "images": [], "xdomain": [15.0, 27.0], "ylim": [0.10000000000000001, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [16.0, 18.0, 20.0, 22.0, 24.0, 26.0, 36.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 4, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el8294956635536"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294956635536pts"}], "id": "el8294955075152", "ydomain": [0.10000000000000001, 1.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[16.0, 0.8509035050228704], [18.0, 0.7435507831105497], [20.0, 0.6206110146304127], [22.0, 0.614553300460102], [24.0, 0.5129640585801098], [26.0, 0.2554026369471103], [36.0, 0.0]]}, "id": "el8294939295376"});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el82949392953768576710009", {"axes": [{"xlim": [15.0, 27.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294955145296"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el8294955196752"}], "zoomable": true, "images": [], "xdomain": [15.0, 27.0], "ylim": [0.10000000000000001, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [16.0, 18.0, 20.0, 22.0, 24.0, 26.0, 36.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 4, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el8294956635536"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294956635536pts"}], "id": "el8294955075152", "ydomain": [0.10000000000000001, 1.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"fontsize": 12, "fmt": ".3g", "type": "mouseposition"}], "data": {"data01": [[16.0, 0.8509035050228704], [18.0, 0.7435507831105497], [20.0, 0.6206110146304127], [22.0, 0.614553300460102], [24.0, 0.5129640585801098], [26.0, 0.2554026369471103], [36.0, 0.0]]}, "id": "el8294939295376"});
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#                  mpld3.draw_figure("fig_el82949392953768576710009", {"axes": [{"xlim": [15.0, 27.0], "yscale": "log", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294955145296"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Delta Etotal/natom [meV]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.08048551005701865, 0.5], "rotation": -90.0, "id": "el8294955196752"}], "zoomable": true, "images": [], "xdomain": [15.0, 27.0], "ylim": [0.10000000000000001, 1.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": [16.0, 18.0, 20.0, 22.0, 24.0, 26.0, 36.0]}, {"scale": "log", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 4, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 3.0, "data": "data01", "id": "el8294956635536"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[7.5, 1.3777276490407722e-15], [-7.499999999999998, -7.500000000000002], [-7.500000000000002, 7.499999999999998]], ["M", "L", "L", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294956635536pts"}], "id": "el8294955075152", "ydomain": [0.10000000000000001, 1.0], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoo

# %% [markdown]
# # Convergence of the deltafactor results:

# %%
report.plot_deltafactor_convergence(what=("dfact_meV", "dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949568757929360491376"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949568757929360491376", {"axes": [{"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfact_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.069808467741935484, 0.5], "rotation": -90.0, "id": "el8294957038672"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [0.90000000000000002, 1.3500000000000001], "paths": [], "sharey": [], "sharex": ["el8294957203280"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294957385488"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294957385488pts"}], "id": "el8294956988496", "ydomain": [0.90000000000000002, 1.3500000000000001], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el8294957235600"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$dfactprime_meV", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.070091985887096767, 0.5], "rotation": -90.0, "id": "el8294957259792"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [1.5, 2.2999999999999998], "paths": [], "sharey": [], "sharex": ["el8294956988496"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294957385872"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.474873734 ...

# %% [markdown]
# # Convergence of $\Delta v_0$, $\Delta b_0$, and $\Delta b_1$ (deltafactor tests)

# %%
# Here we plot the difference wrt Wien2k results.
report.plot_deltafactor_convergence(what=("-dfact_meV", "-dfactprime_meV"), show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949550341922759537050"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949550341922759537050", {"axes": [{"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$v0", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.50000000000000044], "rotation": -90.0, "id": "el8294956845200"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [-0.070000000000000007, -0.045000000000000005], "paths": [], "sharey": [], "sharex": ["el8294957062736", "el8294957532560"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294971177936"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294971177936pts"}], "id": "el8294956904080", "ydomain": [-0.070000000000000007, -0.045000000000000005], "collections": [], "xscale": "linear", "bbox": [0.125, 0.66470588235294115, 0.77500000000000002, 0.23529411764705888]}, {"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$b0_GPa", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.082661290322580641, 0.5], "rotation": -90.0, "id": "el8294957507024"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [-2.5, 0.0], "paths": [], "sharey": [], "sharex": ["el8294956904080", "el8294957532560"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294971179536"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.47487373415 ...

# %% [markdown]
# # deltafactor EOS for the different cutoff energies:

# %%
report.plot_deltafactor_eos(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949574081448461356605"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949574081448461356605", {"axes": [{"xlim": [19.0, 22.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294971054800"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el8294971058448"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294982400528"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 16.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2992424242424242], "rotation": -0.0, "id": "el8294982399504"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 18.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.25505050505050503], "rotation": -0.0, "id": "el8294979464592"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 20.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2108585858585858], "rotation": -0.0, "id": "el8294982401680"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 22.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el8294982440784"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 24.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474742], "rotation": -0.0, "id": "el8294982443152"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 26.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el8294982359568"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 36.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909075], "rotation": -0.0, "id": "el8294982361936"}], "zoomable": true, "images": [], "xdomain": [19.0, 22.0], "ylim": [-148.01499999999999, -147.98000000000002], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data04", "id": "el8294982435536"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el8294979501136"}, {"color": "#0010FF", "yindex": 2, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el8294979498512"}, {"color": "#00A4FF", "yindex": 3, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xi ...

# %% [markdown]
# # Convergence of the GBRV lattice parameters:

# %%
report.plot_gbrv_convergence(show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949824324645149900962"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949824324645149900962", {"axes": [{"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el8294979520976"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [-0.125, -0.084999999999999992], "paths": [], "sharey": [], "sharex": ["el8294982529232"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294982594704"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217920558846, -1.8185295477469872], [2.4748737341529163, -2.4748737341529163], [1.8185295477469872, -3.131217920558846], [0.9282108500000001, -3.5], [0.0, -3.5], [-0.9282108500000001, -3.5], [-1.8185295477469872, -3.131217920558846], [-2.4748737341529163, -2.4748737341529163], [-3.131217920558846, -1.8185295477469872], [-3.5, -0.9282108500000001], [-3.5, 0.0], [-3.5, 0.9282108500000001], [-3.131217920558846, 1.8185295477469872], [-2.4748737341529163, 2.4748737341529163], [-1.8185295477469872, 3.131217920558846], [-0.9282108500000001, 3.5], [0.0, 3.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el8294982594704pts"}], "id": "el8294979523536", "ydomain": [-0.125, -0.084999999999999992], "collections": [], "xscale": "linear", "bbox": [0.125, 0.53636363636363638, 0.77500000000000002, 0.36363636363636365]}, {"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Ecut [Ha]", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.1875], "rotation": -0.0, "id": "el8294982668048"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_bcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el8294982655376"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [-0.155, -0.13], "paths": [], "sharey": [], "sharex": ["el8294979523536"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294982595088"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 2, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.13121 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el82949824324645149900962", {"axes": [{"xlim": [15.0, 40.0], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "$\\Delta$gbrv_fcca0_rel_err", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.10786290322580644, 0.5], "rotation": -90.0, "id": "el8294979520976"}], "zoomable": true, "images": [], "xdomain": [15.0, 40.0], "ylim": [-0.125, -0.084999999999999992], "paths": [], "sharey": [], "sharex": ["el8294982529232"], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": "", "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "el8294982594704"}], "markers": [{"edgecolor": "#000000", "facecolor": "#0000FF", "edgewidth": 0.01, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 3.5], [0.9282108500000001, 3.5], [1.8185295477469872, 3.131217920558846], [2.4748737341529163, 2.4748737341529163], [3.131217920558846, 1.8185295477469872], [3.5, 0.9282108500000001], [3.5, 0.0], [3.5, -0.9282108500000001], [3.131217

# %% [markdown]
# # GBRV EOS for the FCC structure:

# %%
report.plot_gbrv_eos(struct_type="fcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949826126245456665913"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949826126245456665913", {"axes": [{"xlim": [14.0, 14.6], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294987281872"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.12046370967741934, 0.5], "rotation": -90.0, "id": "el8294987267408"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294990438544"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 16.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.94886363636363646], "rotation": -0.0, "id": "el8294990398416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 18.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.90467171717171713], "rotation": -0.0, "id": "el8294990400848"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 20.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.86047979797979812], "rotation": -0.0, "id": "el8294990400208"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 22.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.81628787878787878], "rotation": -0.0, "id": "el8294990412048"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 24.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.77209595959595956], "rotation": -0.0, "id": "el8294990414416"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 26.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.72790404040404044], "rotation": -0.0, "id": "el8294990429136"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 36.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.48549507168458783, 0.68371212121212133], "rotation": -0.0, "id": "el8294990435664"}], "zoomable": true, "images": [], "xdomain": [14.0, 14.6], "ylim": [-147.4365, -147.43299999999999], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el8294990397712"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el8294987338512"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el8294990278416"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewi ...

# %% [markdown]
# # GBRV EOS for the BCC structure:

# %%
report.plot_gbrv_eos(struct_type="bcc", show=False)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el82949575155368429003283"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el82949575155368429003283", {"axes": [{"xlim": [14.200000000000001, 14.9], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Volume $\\AA^3$", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.085227272727272735], "rotation": -0.0, "id": "el8294987391376"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Energy (eV)", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.12046370967741934, 0.5], "rotation": -90.0, "id": "el8294990285264"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "None", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [-0.16129032258064516, -0.12499999999999999], "rotation": -0.0, "id": "el8294991105552"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 16.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2992424242424242], "rotation": -0.0, "id": "el8294991103184"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 18.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.25505050505050503], "rotation": -0.0, "id": "el8294991156688"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 20.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.2108585858585858], "rotation": -0.0, "id": "el8294991106128"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 22.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.16666666666666663], "rotation": -0.0, "id": "el8294991100368"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 24.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.12247474747474742], "rotation": -0.0, "id": "el8294991102736"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 26.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.078282828282828273], "rotation": -0.0, "id": "el8294991150224"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "ecut 36.0", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.082885304659498199, 0.034090909090909075], "rotation": -0.0, "id": "el8294991136272"}], "zoomable": true, "images": [], "xdomain": [14.200000000000001, 14.9], "ylim": [-147.4495, -147.446], "paths": [{"edgecolor": "#262626", "facecolor": "#FFFFFF", "edgewidth": 0.3, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "axes", "dasharray": "10,0", "zorder": 1000001.0, "alpha": 1.0, "xindex": 0, "data": "data16", "id": "el8294991143312"}], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#CCCCCC", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [{"color": "#00007F", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "el8295001875088"}, {"color": "#0010FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "el8295001898832"}, {"color": "#00A4FF", "yindex": 1, "coordinates": "data", "dasharray": "6,6", "zorder": 2, "alpha": ...

# %% [markdown]
# # Comparison with the other pseudos in this table

# %%
from pseudo_dojo import get_pseudos
pseudos = get_pseudos(".")
if len(pseudos) > 1:
    pseudos.dojo_compare()
