# %%
from pseudo_dojo.core.pseudos import dojopseudo_from_file, DojoTable
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

keys = ["high_dfact_meV", "high_gbrv_bcc_a0_rel_err", "high_gbrv_fcc_a0_rel_err",
        "high_b0_GPa", "high_v0", "high_b1"]

# %%
old_pseudos = DojoTable.from_dir("ONCVPSP-PBE-PDv0.3/")

# %%
new_pseudos = DojoTable.from_dir("ONCVPSP-PBE-PDv0.4/")

# %% [markdown]
# ## dataframe with new pseudos (new optimizer, same input file as in PDv0.3)

# %%
new_frame, errors = new_pseudos.get_dojo_dataframe()
new_frame["oncvpsp"] = "new"
new_frame["name"] = new_frame.index
new_frame[keys]
# Out:
#                high_dfact_meV  high_gbrv_bcc_a0_rel_err  \
# H.psp8               0.148234                 -0.010512
# F.psp8               0.129881                 -0.599230
# P-sp.psp8            0.445419                 -0.496776
# P.psp8               0.142140                 -0.476330
# Cr-sp.psp8          10.499055                 -0.071567
# Mn-sp.psp8           8.025753                 -0.055814
# Fe-sp.psp8           5.599088                 -0.152357
# Zn.psp8              0.504695                 -0.033558
# As.psp8              0.657894                 -0.123279
# Ru-sp.psp8           2.115791                 -0.034162
# Rh-sp.psp8           2.564075                 -0.047008
# Cd.psp8              0.494949                 -0.299431
# Te.psp8              0.052355                  0.025122
# Hf-fsp.psp8          0.327103                 -0.045699
# Hf-sp.psp8           0.614422                 -0.005018
# Tl-d-new.psp8        0.069113                 -0.127418
# Tl-d.psp8            0.084791                 -0.123033
# Pb-d.psp8            0.063435                 -0.050197
#
#                high_gbrv_fcc_a0_rel_err  high_b0_GPa    high_v0   high_b1
# H.psp8                        -0.014088    10.293841  17.322217  2.657476
# F.psp8                        -0.563391    33.751469  19.183131  4.012054
# P-sp.psp8                     -0.559037    68.016766  21.441461  4.328873
# P.psp8                        -0.553030    67.829287  21.462507  4.317492
# Cr-sp.psp8                    -0.022471   143.801167  12.075476  6.835678
# Mn-sp.psp8                    -0.047566   121.033635  11.739277  3.178355
# Fe-sp.psp8                    -0.078737   158.846314  11.476187  9.076524
# Zn.psp8                       -0.044089    74.027171  15.224571  5.532846
# As.psp8                       -0.112273    68.106574  22.545385  4.190018
# Ru-sp.psp8                    -0.007770   310.961695  13.793422  4.887378
# Rh-sp.psp8                    -0.015709   254.794900  14.086230  5.230208
# Cd.psp8                       -0.295113    44.330841  22.788891  6.394190
# Te.psp8                        0.038351    44.805633  34.970915  4.705671
# Hf-fsp.psp8                   -0.043489   106.724683  22.547201  3.437055
# Hf-sp.psp8                    -0.025461   108.281802  22.557424  3.454226
# Tl-d-new.psp8                 -0.030998    26.487363  31.399332  5.425958
# Tl-d.psp8                     -0.026626    26.481736  31.403467  5.426219
# Pb-d.psp8                     -0.053791    39.919233  31.998516  4.855907

# %%
new_frame[keys].describe()
# Out:
#        high_dfact_meV  high_gbrv_bcc_a0_rel_err  high_gbrv_fcc_a0_rel_err  \
# count       18.000000                 18.000000                 18.000000
# mean         1.807677                 -0.151459                 -0.136405
# std          3.067077                  0.187458                  0.205877
# min          0.052355                 -0.599230                 -0.563391
# 25%          0.132946                 -0.146123                 -0.103889
# 50%          0.470184                 -0.063690                 -0.043789
# 75%          1.751317                 -0.037046                 -0.023219
# max         10.499055                  0.025122                  0.038351
#
#        high_b0_GPa    high_v0    high_b1
# count    18.000000  18.000000  18.000000
# mean     94.916339  21.000867   4.885896
# std      80.691389   7.473000   1.508869
# min      10.293841  11.476187   2.657476
# 25%      41.022135  14.370815   4.056545
# 50%      68.061670  21.451984   4.780789
# 75%     117.845677  22.731024   5.426153
# max     310.961695  34.970915   9.076524

# %% [markdown]
# ## Results obtained with PDv0.3 (old optimizer)

# %%
# Select old pseudos with a corresponding entry in the new_frame
old_frame, errors = old_pseudos.get_dojo_dataframe()
old_frame["oncvpsp"] = "old"
old_frame["name"] = old_frame.index
old_frame = old_frame.ix[new_frame.index]
old_frame[keys]
# Out:
#                high_dfact_meV  high_gbrv_bcc_a0_rel_err  \
# H.psp8               0.115844                  0.005722
# F.psp8               0.100828                 -0.597490
# P-sp.psp8            0.454260                 -0.497972
# P.psp8               0.151933                 -0.478323
# Cr-sp.psp8          10.486710                 -0.071757
# Mn-sp.psp8           8.015366                 -0.055917
# Fe-sp.psp8           5.793603                 -0.142032
# Zn.psp8              0.660498                 -0.042731
# As.psp8              0.612549                 -0.119992
# Ru-sp.psp8           2.141423                 -0.033035
# Rh-sp.psp8           2.573790                 -0.046412
# Cd.psp8              1.732234                 -0.254382
# Te.psp8              0.425503                  0.062193
# Hf-fsp.psp8          0.325406                 -0.045369
# Hf-sp.psp8           2.890423                  0.144628
# Tl-d-new.psp8             NaN                       NaN
# Tl-d.psp8            0.106410                 -0.118658
# Pb-d.psp8            0.067717                 -0.047542
#
#                high_gbrv_fcc_a0_rel_err  high_b0_GPa    high_v0   high_b1
# H.psp8                         0.006048    10.298018  17.336656  2.666449
# F.psp8                        -0.564195    33.781714  19.178827  4.015261
# P-sp.psp8                     -0.560413    68.046088  21.441151  4.286808
# P.psp8                        -0.555373    67.839559  21.461789  4.317458
# Cr-sp.psp8                    -0.022481   143.796557  12.075118  6.837938
# Mn-sp.psp8                    -0.047509   121.026585  11.738924  3.173264
# Fe-sp.psp8                    -0.068393   158.261621  11.481607  9.079073
# Zn.psp8                       -0.054427    74.253774  15.221220  5.538618
# As.psp8                       -0.110322    68.111932  22.548402  4.192272
# Ru-sp.psp8                    -0.006876   310.971815  13.793774  4.891385
# Rh-sp.psp8                    -0.015129   254.804271  14.086401  5.230104
# Cd.psp8                       -0.254004    43.961983  22.811496  6.385928
# Te.psp8                        0.069078    44.732136  35.019833  4.707239
# Hf-fsp.psp8                   -0.043325   106.744822  22.547197  3.427729
# Hf-sp.psp8                     0.127719   107.801334  22.655515  3.483771
# Tl-d-new.psp8                       NaN          NaN        NaN       NaN
# Tl-d.psp8                     -0.022403    26.451332  31.407851  5.425053
# Pb-d.psp8                     -0.051142    39.914656  32.000729  4.855355

# %%
old_frame[keys].describe()
# Out:
#        high_dfact_meV  high_gbrv_bcc_a0_rel_err  high_gbrv_fcc_a0_rel_err  \
# count       17.000000                 17.000000                 17.000000
# mean         2.156147                 -0.137592                 -0.127832
# std          3.089126                  0.204293                  0.220298
# min          0.067717                 -0.597490                 -0.564195
# 25%          0.151933                 -0.142032                 -0.110322
# 50%          0.612549                 -0.055917                 -0.047509
# 75%          2.573790                 -0.042731                 -0.015129
# max         10.486710                  0.144628                  0.127719
#
#        high_b0_GPa    high_v0    high_b1
# count    17.000000  17.000000  17.000000
# mean     98.870482  20.400382   4.853747
# std      81.276391   7.232236   1.548512
# min      10.298018  11.481607   2.666449
# 25%      43.961983  14.086401   4.015261
# 50%      68.111932  21.441151   4.707239
# 75%     121.026585  22.655515   5.425053
# max     310.971815  35.019833   9.079073

# %% [markdown]
# ## Difference between the results obtained with old and new pseudos

# %%
new_frame[keys] - old_frame[keys]
# Out:
#                high_dfact_meV  high_gbrv_bcc_a0_rel_err  \
# H.psp8               0.032390                 -0.016233
# F.psp8               0.029053                 -0.001740
# P-sp.psp8           -0.008840                  0.001196
# P.psp8              -0.009792                  0.001993
# Cr-sp.psp8           0.012345                  0.000190
# Mn-sp.psp8           0.010387                  0.000103
# Fe-sp.psp8          -0.194515                 -0.010325
# Zn.psp8             -0.155803                  0.009173
# As.psp8              0.045346                 -0.003287
# Ru-sp.psp8          -0.025632                 -0.001127
# Rh-sp.psp8          -0.009715                 -0.000596
# Cd.psp8             -1.237285                 -0.045049
# Te.psp8             -0.373148                 -0.037071
# Hf-fsp.psp8          0.001697                 -0.000330
# Hf-sp.psp8          -2.276001                 -0.149646
# Tl-d-new.psp8             NaN                       NaN
# Tl-d.psp8           -0.021619                 -0.004375
# Pb-d.psp8           -0.004282                 -0.002655
#
#                high_gbrv_fcc_a0_rel_err  high_b0_GPa   high_v0   high_b1
# H.psp8                        -0.020136    -0.004177 -0.014439 -0.008973
# F.psp8                         0.000804    -0.030245  0.004304 -0.003207
# P-sp.psp8                      0.001375    -0.029322  0.000310  0.042064
# P.psp8                         0.002343    -0.010272  0.000718  0.000034
# Cr-sp.psp8                     0.000010     0.004610  0.000358 -0.002260
# Mn-sp.psp8                    -0.000057     0.007050  0.000353  0.005091
# Fe-sp.psp8                    -0.010344     0.584693 -0.005420 -0.002549
# Zn.psp8                        0.010338    -0.226603  0.003352 -0.005772
# As.psp8                       -0.001952    -0.005358 -0.003018 -0.002255
# Ru-sp.psp8                    -0.000893    -0.010120 -0.000353 -0.004007
# Rh-sp.psp8                    -0.000580    -0.009371 -0.000171  0.000104
# Cd.psp8                       -0.041109     0.368858 -0.022606  0.008263
# Te.psp8                       -0.030727     0.073497 -0.048918 -0.001569
# Hf-fsp.psp8                   -0.000164    -0.020140  0.000004  0.009326
# Hf-sp.psp8                    -0.153181     0.480467 -0.098090 -0.029545
# Tl-d-new.psp8                       NaN          NaN       NaN       NaN
# Tl-d.psp8                     -0.004223     0.030404 -0.004384  0.001165
# Pb-d.psp8                     -0.002649     0.004577 -0.002213  0.000552

# %%
# Concatenate and sort by Z to prepare seaborn calls
data = pd.concat([old_frame, new_frame])
data.sort_values("Z");

# %%
# Draw barplot with the deltfactor computed at the highest cutoff-energy
sns.factorplot(y="name", x="high_dfact_meV", hue="oncvpsp", data=data,
               size=6, kind="bar", palette="muted", orient="h")
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Draw barplot with the relative error in the GBRV FCC benchmark
g = sns.factorplot(y="name", x="high_gbrv_fcc_a0_rel_err", hue="oncvpsp", data=data,
                   size=6, kind="bar", palette="muted", orient="h")
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Draw barplot with the relative error in the GBRV BCC benchmark
g = sns.factorplot(y="name", x="high_gbrv_bcc_a0_rel_err", hue="oncvpsp", data=data,
                   size=6, kind="bar", palette="muted", orient="h")
# Out:
# <img src="data:image/png;base64,..." width="600">
